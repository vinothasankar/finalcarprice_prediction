# %%
import pandas as pd
import ast

bangalore_cars = pd.read_excel('C:/Users/ncssa/Downloads/bangalore_cars.xlsx')
chennai_cars = pd.read_excel('C:/Users/ncssa/Downloads/chennai_cars.xlsx')
hyderabad_cars = pd.read_excel('C:/Users/ncssa/Downloads/hyderabad_cars.xlsx')
kolkata_cars = pd.read_excel('C:/Users/ncssa/Downloads/kolkata_cars.xlsx')
jaipur_cars = pd.read_excel('C:/Users/ncssa/Downloads/jaipur_cars.xlsx')
delhi_cars = pd.read_excel('C:/Users/ncssa/Downloads/delhi_cars.xlsx')

# %%
def car_data(df):
    d1_list = []
    d2_list = []
    d3_list = []
    d4_list = []
    d5_list = []
    for row in range(len(df)):
        a = df.iloc[row]["new_car_detail"]
        res = ast.literal_eval(a)
        d1_df = pd.DataFrame([res])
        d1_list.append(d1_df)
        
        b = df.iloc[row]["new_car_overview"]
        res = ast.literal_eval(b)
        d2_df = pd.DataFrame([res])
        key_lst=[]
        val_lst=[]
        for i in d2_df["top"]:
            for j in i:
                key_lst.append(j["key"])
                val_lst.append(j["value"])
        result = dict(zip(key_lst, val_lst))
        d2_df = pd.DataFrame([result])
        d2_list.append(d2_df)
        
        c = df.iloc[row]["new_car_feature"]
        res = ast.literal_eval(c)
        d3_df = pd.DataFrame()
        for i in res.keys():
            if i == 'heading':
                d3_df[res[i]] = [len(res["top"])]
            elif i == 'data':
                for a in res[i]:
                    for b in a:
                        if b == 'heading':
                            d3_df[a[b]] = [len(a["list"])]
        d3_list.append(d3_df)
        
        d = df.iloc[row]["new_car_specs"]
        res = ast.literal_eval(d)
        d4_df = pd.DataFrame()
        for i in res.keys():
            if i == 'top':
                for j in res[i]:
                    d4_df[j["key"]] = [j["value"]]
            elif i == 'data':
                for a in res[i]:
                    for b in a:
                        if b == 'heading':
                            d4_df[a[b]] = [len(a["list"])]
                        elif b == 'list':
                            for j in a[b]:
                                d4_df[j["key"]] = [j["value"]]
        d4_df = d4_df.rename(columns={'Seats':'Seats_capacity'})
        d4_list.append(d4_df)
        
        e = df.iloc[row]["car_links"]
        d5_df = pd.DataFrame([e])
        d5_list.append(d5_df) 

       
        
    d1 = pd.concat(d1_list, ignore_index=True)
    d2 = pd.concat(d2_list, ignore_index=True)
    d3 = pd.concat(d3_list, ignore_index=True)
    d4 = pd.concat(d4_list, ignore_index=True)
    d5 = pd.concat(d5_list, ignore_index=True)
    
    
    df = d1.join(d2).join(d3).join(d4).join(d5)
    df.rename(columns={0:"car_links"},inplace = True)
    
    return df

# %%
df_newbangalore_cars = car_data(bangalore_cars)
df_newchennai_cars = car_data(chennai_cars)
df_newdelhi_cars = car_data(delhi_cars)
df_newjaipur_cars = car_data(jaipur_cars)
df_newhyderabad_cars = car_data(hyderabad_cars)
df_newkolkata_cars = car_data(kolkata_cars)
df_newbangalore_cars['city'] = "Bangalore"
df_newchennai_cars['city'] = "Chennai"
df_newdelhi_cars['city'] = "Delhi"
df_newjaipur_cars['city'] = "Jaipur"
df_newhyderabad_cars['city'] = "Hyderabad"
df_newkolkata_cars['city'] = "Kolkata"

# %%
df_newcity_cars = pd.concat([df_newbangalore_cars,df_newchennai_cars,df_newdelhi_cars,df_newjaipur_cars,df_newhyderabad_cars,df_newkolkata_cars],ignore_index = True)

# %%
df_newcity_cars
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Top Speed  \
# ...

# %%
df_newcity_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 78 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   it                             8369 non-null   int64
#  1   ft                             8369 non-null   object
#  2   bt                             8369 non-null   object
#  3   km                             8369 non-null   object
#  4   transmission                   8369 non-null   object
#  5   ownerNo                        8369 non-null   int64
#  6   owner                          8369 non-null   object
#  7   oem                            8369 non-null   object
#  8   model                          8369 non-null   object
#  9   modelYear                      8369 non-null   int64
#  10  centralVariantId               8369 non-null   int64
#  11  variantName                    8369 non-null   object
# ...

# %%
df_newcity_cars.describe()
# Out:
#            it      ownerNo    modelYear  centralVariantId  \
# count  8369.0  8369.000000  8369.000000       8369.000000
# mean      0.0     1.360139  2016.503286       4962.537340
# std       0.0     0.641958     3.921465       2747.040479
# min       0.0     0.000000  1985.000000          5.000000
# 25%       0.0     1.000000  2014.000000       2042.000000
# 50%       0.0     1.000000  2017.000000       5320.000000
# 75%       0.0     2.000000  2019.000000       7121.000000
# max       0.0     5.000000  2023.000000      11098.000000
#
#        Year of Manufacture     Features  Comfort & Convenience     Interior  \
# count          8349.000000  8369.000000            8301.000000  8292.000000
# mean           2016.547850     8.785160              15.734610    10.303304
# std               3.811882     0.911979               6.403504     2.430612
# min            2002.000000     0.000000               1.000000     1.000000
# ...

# %%
# Save the DataFrame as a CSV file
df_newcity_cars.to_csv('C:/Users/ncssa/Downloads/df_newcity_cars.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('C:/Users/ncssa/Downloads/df_newcity_cars.csv')
df
# Out:
# C:\Users\ncssa\AppData\Local\Temp\ipykernel_12712\2681987655.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/ncssa/Downloads/df_newcity_cars.csv')
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 78 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   it                             8369 non-null   int64
#  1   ft                             8369 non-null   object
#  2   bt                             8365 non-null   object
#  3   km                             8369 non-null   object
#  4   transmission                   8369 non-null   object
#  5   ownerNo                        8369 non-null   int64
#  6   owner                          8369 non-null   object
#  7   oem                            8369 non-null   object
#  8   model                          8369 non-null   object
#  9   modelYear                      8369 non-null   int64
#  10  centralVariantId               8369 non-null   int64
#  11  variantName                    8369 non-null   object
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame
# Drop columns that are empty
df = df.dropna(axis=1, how='all')

# Drop columns that have only one unique value
df = df.loc[:, df.nunique() > 1]

# Display the cleaned DataFrame
print(df)
# Out:
#           ft         bt        km transmission  ownerNo      owner  \
# 0     Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1     Petrol        SUV    32,706       Manual        2  2nd Owner
# 2     Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3     Petrol      Sedan    17,794       Manual        1  1st Owner
# 4     Diesel        SUV    60,000       Manual        1  1st Owner
# ...      ...        ...       ...          ...      ...        ...
# 8364  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  ...  \
# 0            Maruti         Maruti Celerio       2015              3979  ...
# ...

# %%
import pandas as pd

def col_info(df, column_name):
    """
    Print information about a specific column in a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing the column.
    column_name (str): The name of the column to analyze.
    """
    if column_name not in df.columns:
        print(f"Column '{column_name}' does not exist in the DataFrame.")
        return
    
    col = df[column_name]
    
    print(f"Column Name: {column_name}, "
          f"Total Null: {col.isnull().sum()}, "
          f"Number of Unique Values: {col.nunique()}, "
          f"Unique Values: {col.unique()}, "
          f"Data Type: {col.dtype}")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   bt                             8365 non-null   object
#  1   km                             8369 non-null   int64
#  2   transmission                   8369 non-null   object
#  3   ownerNo                        8369 non-null   int64
#  4   model                          8369 non-null   object
#  5   modelYear                      8369 non-null   int64
#  6   price                          8259 non-null   float64
#  7   priceActual                    1670 non-null   float64
#  8   Insurance Validity             8365 non-null   object
#  9   Fuel Type                      8369 non-null   object
#  10  RTO                            7475 non-null   object
#  11  Features                       8369 non-null   int64
# ...

# %%
num_col=['km','ownerNo','Mileage','No of Cylinder','Wheel Size','Cargo Volumn','No Door Numbers','Turning Radius','Ground Clearance Unladen',
         'Acceleration','Top Speed','Miscellaneous','Values per Cylinder','Kerb Weight','Gross Weight','Rear Tread','Front Tread','Wheel Base',
         'Height','Width','Length','Compression Ratio','Dimensions & Capacity','modelYear','BoreX Stroke','Displacement',
         'Engine and Transmission','Seating Capacity','Features','Comfort & Convenience','Interior','Exterior','Safety',
         'Entertainment & Communication','Torque']
cat_col=['Fuel Type','bt','Drive Type','Front Brake Type','Rear Brake Type','Tyre Type','Insurance Validity','Steering Type','RTO','Engine Type',
         'Gear Box','Value Configuration','Fuel Suppy System','Turbo Charger','Super Charger','model','Color','car_links','city']
lecode = ['transmission']
dup_col = ['owner','Engine Displacement','oem','centralVariantId','variantName','Registration Year','ft','Kms Driven',
           'Transmission','Year of Manufacture','Seats','Engine','Alloy Wheel Size','Ownership','Seats_capacity']
spl_col = ['Max Power','Max Torque','price','priceActual']

# %%
print(len(num_col)+len(cat_col)+len(lecode)+len(dup_col)+len(spl_col))
# Out:
# 74

# %%
import numpy as np
import pandas as pd

def convert_price(value):
    # Check if the value is NaN
    if pd.isna(value):
        return np.nan
    
    # Remove the currency symbol and whitespace
    clean_value = value.replace('₹', '').strip()
    
    # Check for "Lakh" and "Crore" keywords and extract the numeric part
    if 'Lakh' in clean_value or 'Lakhs' in clean_value or 'lakh' in clean_value or 'lakhs' in clean_value:
        numeric_part = pd.to_numeric(clean_value.replace('Lakh', '').replace('Lakhs', '').replace('lakh', '').replace('lakhs', '').strip(), errors='coerce')
        return numeric_part * 100000 if numeric_part is not np.nan else np.nan
    elif 'Crore' in clean_value or 'Crores' in clean_value or 'crore' in clean_value or 'crores' in clean_value:
        numeric_part = pd.to_numeric(clean_value.replace('Crore', '').replace('Crores', '').replace('crore', '').replace('crores', '').strip(), errors='coerce')
        return numeric_part * 10000000 if numeric_part is not np.nan else np.nan
    else:
        return pd.to_numeric(clean_value, errors='coerce')  # Directly convert if there are no keywords

# Apply the function to the 'price' column and store the result in 'priceActual'
df['priceActual'] = df['priceActual'].apply(convert_price)
df['price'] = df['price'].apply(convert_price)

# %%
# Dropping specified columns from the DataFrame
df = df.drop(columns=dup_col)

# Extracting the numerical part before "@" and converting to numeric
df['Max Power'] = pd.to_numeric(df['Max Power'].str.split('@').str[0].str.replace(r'[^0-9.]', '', regex=True), errors='coerce')
df['Max Torque'] = pd.to_numeric(df['Max Torque'].str.split('@').str[0].str.replace(r'[^0-9.]', '', regex=True), errors='coerce')
df[['Max Power','Max Torque']]


for col in num_col:
    # Remove all non-digit characters, including periods, and convert to numeric type
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(r'[^0-9.]', '', regex=True), errors='coerce')
    
num_col.extend(spl_col)
print(num_col)

df.info()
# Out:
# ['km', 'ownerNo', 'Mileage', 'No of Cylinder', 'Wheel Size', 'Cargo Volumn', 'No Door Numbers', 'Turning Radius', 'Ground Clearance Unladen', 'Acceleration', 'Top Speed', 'Miscellaneous', 'Values per Cylinder', 'Kerb Weight', 'Gross Weight', 'Rear Tread', 'Front Tread', 'Wheel Base', 'Height', 'Width', 'Length', 'Compression Ratio', 'Dimensions & Capacity', 'modelYear', 'BoreX Stroke', 'Displacement', 'Engine and Transmission', 'Seating Capacity', 'Features', 'Comfort & Convenience', 'Interior', 'Exterior', 'Safety', 'Entertainment & Communication', 'Torque', 'Max Power', 'Max Torque', 'price', 'priceActual']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   bt                             8365 non-null   object
#  1   km                             8369 non-null   int64
# ...

# %%
df['Seating Capacity']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 8364    5.0
# 8365    5.0
# 8366    5.0
# 8367    5.0
# 8368    5.0
# Name: Seating Capacity, Length: 8369, dtype: float64

# %%
df
# Out:
#              bt      km transmission  ownerNo                  model  \
# 0     Hatchback  120000       Manual        3         Maruti Celerio
# 1           SUV   32706       Manual        2          Ford Ecosport
# 2     Hatchback   11949       Manual        1             Tata Tiago
# 3         Sedan   17794       Manual        1          Hyundai Xcent
# 4           SUV   60000       Manual        1     Maruti SX4 S Cross
# ...         ...     ...          ...      ...                    ...
# 8364  Hatchback   10000       Manual        1         Maruti Celerio
# 8365  Hatchback  120000       Manual        1        Maruti Alto 800
# 8366      Sedan   50000    Automatic        3  Mercedes-Benz C-Class
# 8367  Hatchback   40000       Manual        1            Maruti Ritz
# 8368        SUV  120000       Manual        2         Renault Duster
#
#       modelYear     price  priceActual     Insurance Validity Fuel Type  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   bt                             8365 non-null   object
#  1   km                             8369 non-null   int64
#  2   transmission                   8369 non-null   object
#  3   ownerNo                        8369 non-null   int64
#  4   model                          8369 non-null   object
#  5   modelYear                      8369 non-null   int64
#  6   price                          8259 non-null   float64
#  7   priceActual                    1670 non-null   float64
#  8   Insurance Validity             8365 non-null   object
#  9   Fuel Type                      8369 non-null   object
#  10  RTO                            7475 non-null   object
#  11  Features                       8369 non-null   int64
# ...

# %%
# Save the DataFrame as a CSV file
df.to_csv('C:/Users/ncssa/Downloads/df_cars.csv', index=False)

# %%
df = pd.read_csv('C:/Users/ncssa/Downloads/df_cars.csv')
df
# Out:
#              bt      km transmission  ownerNo                  model  \
# 0     Hatchback  120000       Manual        3         Maruti Celerio
# 1           SUV   32706       Manual        2          Ford Ecosport
# 2     Hatchback   11949       Manual        1             Tata Tiago
# 3         Sedan   17794       Manual        1          Hyundai Xcent
# 4           SUV   60000       Manual        1     Maruti SX4 S Cross
# ...         ...     ...          ...      ...                    ...
# 8364  Hatchback   10000       Manual        1         Maruti Celerio
# 8365  Hatchback  120000       Manual        1        Maruti Alto 800
# 8366      Sedan   50000    Automatic        3  Mercedes-Benz C-Class
# 8367  Hatchback   40000       Manual        1            Maruti Ritz
# 8368        SUV  120000       Manual        2         Renault Duster
#
#       modelYear     price  priceActual     Insurance Validity Fuel Type  ...  \
# ...

# %%
cat_col
# Out:
# ['Fuel Type',
#  'bt',
#  'Drive Type',
#  'Front Brake Type',
#  'Rear Brake Type',
#  'Tyre Type',
#  'Insurance Validity',
#  'Steering Type',
#  'RTO',
#  'Engine Type',
#  'Gear Box',
#  'Value Configuration',
#  'Fuel Suppy System',
#  'Turbo Charger',
#  'Super Charger',
#  'model',
#  'Color',
#  'car_links',
#  'city']

# %%
import pandas as pd
# Standardize values by removing spaces, converting to lowercase, and simplifying terms
df['Drive Type'] = df['Drive Type'].str.strip().str.lower()

# Define standard terms
standard_drive_types = {
    'fwd': ['fwd', 'front wheel drive'],
    'rwd': ['rwd', 'rear wheel drive', 'rear wheel drive with esp', 'rwd(with mtt)'],
    'awd': ['awd', 'all wheel drive', 'permanent all-wheel drive quattro', 'awd integrated management'],
    '4x4': ['4x4', '4 wd', '4wd', '4x4'],
    '4x2': ['4x2', '2 wd', '2wd', 'two wheel drive']
}

# Map the drive types to their standard forms
def standardize_drive_type(value):
    for standard, variants in standard_drive_types.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Drive Type'] = df['Drive Type'].apply(standardize_drive_type)



# Standardize values by removing spaces, converting to lowercase, and simplifying terms
df['Front Brake Type'] = df['Front Brake Type'].str.strip().str.lower()

# Define standard terms
standard_brake_types = {
    'ventilated disc': [
        'ventilated disc', 'ventilated discs', 'ventilated disk', 'ventilated disc ',
        'ventilated disc', 'ventilated disc', 'ventilated disc', 'ventilated disk', 'ventilated disc',
        'booster assisted ventilated disc', 'ventilated disc', 'ventilated disc', 'caliper ventilated disc',
        'ventilated disc', 'ventilated disc', 'ventillated disc', 'ventilated disc','vantilated disc','ventlated disc',
    ],
    'disc': [
        'disc', 'disc ', ' disc', 'disc & caliper type', 'disc, 236 mm', 'multilateral disc',
        'solid disc', 'disk', 'discs', 'disc brakes', 'disc,internally ventilated ', 'solid disc','disc,internally ventilated'
    ],
    'drum': ['drum'],
    'electric parking brake': ['electric parking brake'],
    'abs': ['abs'],
    'hydraulic dual circuit': [
        'vacuum assisted hydraulic dual circuit w', 'mechanical-hydraulic dual circuit',
        'tandem master cylinder with servo assist'
    ]
}

# Map the brake types to their standard forms
def standardize_brake_type(value):
    for standard, variants in standard_brake_types.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Front Brake Type'] = df['Front Brake Type'].apply(standardize_brake_type)



# Standardize values by removing spaces, converting to lowercase, and simplifying terms
df['Rear Brake Type'] = df['Rear Brake Type'].str.strip().str.lower()

# Define standard terms
standard_brake_types = {
    'drum': [
        'drum', 'self adjusting drum', 'drum ', 'drums', 'self-adjusting drum', 'self adjusting drums',
        'drums 180 mm', 'booster assisted drum', 'leading-trailing drum', 'leading & trailing drum',
        'ventilated drum', 'drum`', 'drum in disc', 'drum in discs', '228.6 mm dia, drums on rear wheels'
    ],
    'solid disc': ['solid disc', 'solid disc '],
    'ventilated disc': [
        'ventilated disc', 'ventilated discs', 'ventilated disc ', 'ventialte disc'
    ],
    'disc': [
        'disc', 'disc ', 'discs', 'disc & caliper type', 'disc & drum'
    ],
    'electric parking brake': ['electric parking brake'],
    'hydraulic dual circuit': [
        'vacuum assisted hydraulic dual circuit w', 'mechanical-hydraulic dual circuit'
    ]
}

# Map the brake types to their standard forms
def standardize_brake_type(value):
    for standard, variants in standard_brake_types.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Rear Brake Type'] = df['Rear Brake Type'].apply(standardize_brake_type)



# Standardize values by removing extra spaces, converting to lowercase, and simplifying terms
df['Tyre Type'] = df['Tyre Type'].str.strip().str.lower()

# Define standard terms
standard_tyre_types = {
    'tubeless radial': [
        'tubeless, radial', 'tubeless,radial', 'radial, tubeless', 'tubeless radial tyres',
        'radial tubeless', 'tubeless radial', 'radial,tubeless', 'tubeless tyres, radial',
        'tubeless radials tyre', 'tubeless, radials', 'tubless, radial', 'tubless,radial',
        'radial tyres', 'tubeless radials', 'tubeless','tubeless,radials'
    ],
    'runflat': [
        'runflat tyres', 'runflat tyre', 'run-flat', 'runflat', 'tubeless,runflat',
        'runflat,radial', 'tubeless. runflat', 'tubeless, runflat'
    ],
    'radial with tube': ['radial with tube'],
    'tubeless all terrain': ['tubeless tyres all terrain'],
    'tubeless mud terrain': ['tubeless tyres mud terrain'],
    'tubeless tyre': ['tubeless tyre', 'tubeless tyres', 'tubeless ']
}

# Map the tyre types to their standard forms
def standardize_tyre_type(value):
    for standard, variants in standard_tyre_types.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Tyre Type'] = df['Tyre Type'].apply(standardize_tyre_type)




# Standardize values by stripping spaces and converting to lowercase
df['Insurance Validity'] = df['Insurance Validity'].str.strip().str.lower()

# Define standard terms
standard_insurance_validity = {
    'third party': ['third party insurance', 'third party'],
    'comprehensive': ['comprehensive'],
    'zero dep': ['zero dep'],
    'not available': ['not available'],
    '1 year': ['1'],
    '2 years': ['2']
}

# Map the insurance validity to their standard forms
def standardize_insurance_validity(value):
    for standard, variants in standard_insurance_validity.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Insurance Validity'] = df['Insurance Validity'].apply(standardize_insurance_validity)




# Standardize values by stripping spaces and converting to lowercase
df['Steering Type'] = df['Steering Type'].str.strip().str.lower()

# Define standard terms
standard_steering_types = {
    'power': ['power'],
    'electric': ['electric', 'epas', 'electrical', 'electronic'],
    'manual': ['manual'],
    'hydraulic': ['hydraulic']
}

# Map the steering types to their standard forms
def standardize_steering_type(value):
    for standard, variants in standard_steering_types.items():
        if value in variants:
            return standard
    return value  # Return the original if not in the standard list

# Apply the standardization function
df['Steering Type'] = df['Steering Type'].apply(standardize_steering_type)




# Standardize values by stripping spaces and converting to uppercase
df['RTO'] = df['RTO'].str.strip().str.upper()



df['Engine Type'] = df['Engine Type'].str.strip().str.upper()




df['Fuel Suppy System'] = df['Fuel Suppy System'].str.strip().str.upper()



df['Gear Box'] = df['Gear Box'].str.strip().str.upper()


df['Value Configuration'] = df['Value Configuration'].str.strip().str.upper()


df['Turbo Charger'] = df['Turbo Charger'].str.strip().str.upper()



df['Super Charger'] = df['Super Charger'].str.strip().str.upper()



df['Color'] = df['Color'].str.strip().str.lower()

# %%
df
# Out:
#              bt      km transmission  ownerNo                  model  \
# 0     Hatchback  120000       Manual        3         Maruti Celerio
# 1           SUV   32706       Manual        2          Ford Ecosport
# 2     Hatchback   11949       Manual        1             Tata Tiago
# 3         Sedan   17794       Manual        1          Hyundai Xcent
# 4           SUV   60000       Manual        1     Maruti SX4 S Cross
# ...         ...     ...          ...      ...                    ...
# 8364  Hatchback   10000       Manual        1         Maruti Celerio
# 8365  Hatchback  120000       Manual        1        Maruti Alto 800
# 8366      Sedan   50000    Automatic        3  Mercedes-Benz C-Class
# 8367  Hatchback   40000       Manual        1            Maruti Ritz
# 8368        SUV  120000       Manual        2         Renault Duster
#
#       modelYear     price  priceActual Insurance Validity Fuel Type  ...  \
# ...

# %%
# Save the DataFrame as a CSV file
df.to_csv('C:/Users/ncssa/Downloads/df_newcars.csv', index=False)

# %%
df = pd.read_csv('C:/Users/ncssa/Downloads/df_newcars.csv')
df.head()
# Out:
#           bt      km transmission  ownerNo               model  modelYear  \
# 0  Hatchback  120000       Manual        3      Maruti Celerio       2015
# 1        SUV   32706       Manual        2       Ford Ecosport       2018
# 2  Hatchback   11949       Manual        1          Tata Tiago       2018
# 3      Sedan   17794       Manual        1       Hyundai Xcent       2014
# 4        SUV   60000       Manual        1  Maruti SX4 S Cross       2015
#
#       price  priceActual Insurance Validity Fuel Type  ... Rear Brake Type  \
# 0  400000.0          NaN        third party    Petrol  ...            drum
# 1  811000.0          NaN      comprehensive    Petrol  ...            drum
# 2  585000.0          NaN      comprehensive    Petrol  ...            drum
# 3  462000.0          NaN      comprehensive    Petrol  ...            drum
# 4  790000.0          NaN        third party    Diesel  ...      solid disc
#
# ...

# %%
#Handling Missing Values
import pandas as pd

def null_value_imputer(df):
    # Handling null values
    for i in df.columns:
        if (df[i].isnull().sum() / len(df)) * 100 >= 80:
            df.drop(i, axis=1, inplace=True)
        elif df[i].dtypes in ["int64", "float64"]:
            if df[i].skew() < 0.4 and df[i].skew() > -0.4:
                df[i] = df[i].fillna(df[i].mean())
            else:
                df[i] = df[i].fillna(df[i].median())
        else:
            df[i] = df[i].fillna(df[i].mode()[0])


    #print("Null values after imputation:\n", df.isnull().sum())

    # Removing outliers using IQR method
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Filter the data to remove outliers
        df1 = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

    #print("Data after removing outliers:\n", df.describe())

    return df1
cleandf = null_value_imputer(df)


# Save the DataFrame as a CSV file
cleandf.to_csv('C:/Users/ncssa/Downloads/cleandf_cars.csv', index=False)
